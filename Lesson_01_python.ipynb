# %% [markdown]
# <a href="https://colab.research.google.com/github/zohoor7/DIPLOMA_PART1/blob/main/Lesson_01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **الدرس الاول من مسار الذكاء الاصطناعي  التطبيقي**
